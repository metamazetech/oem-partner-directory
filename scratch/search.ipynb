# %%
with open('c:/Users/Lenovo/.gemini/antigravity/scratch/sanddy-website/oem_portal/app.py', 'r', encoding='utf-8') as f:
    lines = f.readlines()
for i, line in enumerate(lines):
    if '/admin/update-settings' in line:
        print(f"update-settings found at line {i+1}")
        print("".join(lines[i-2:i+20]))
